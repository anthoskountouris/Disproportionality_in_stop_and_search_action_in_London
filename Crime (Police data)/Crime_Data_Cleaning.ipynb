# %% [markdown]
# # Libraries

# %%
import pandas as pd

# %% [markdown]
# # Reading the CSVs

# %%
# Create a list of all the individual DataFrames
dfs = [pd.read_csv(f"../../Data/Police_Data/Crime_Data/crime_2021_wLocations/clean_met_2021_{month:02}.csv") for month in range(1, 13)]

# %%
count = 0 
for df in dfs:
    count += df.shape[0]
    print(df.shape[0])

print("Total Instances:",count)
# Out:
# 65852
# 64522
# 74507
# 72481
# 77888
# 79838
# 80119
# 75879
# 78039
# 81572
# 79268
# 72555
# Total Instances: 902520

# %% [markdown]
# # Concatenating the dataframes into one

# %%
# Concatenate all the DataFrames in the list into one
met_2021 = pd.concat(dfs, ignore_index=True)
met_2021
# Out:
#           Month  Longitude   Latitude                 Borough
# 0       2021-01   0.880386  51.219190                 Ashford
# 1       2021-01   0.145888  51.593835    Barking and Dagenham
# 2       2021-01   0.134947  51.588063    Barking and Dagenham
# 3       2021-01   0.140192  51.582311    Barking and Dagenham
# 4       2021-01   0.141143  51.590873    Barking and Dagenham
# ...         ...        ...        ...                     ...
# 902515  2021-12  -0.606664  51.485155  Windsor and Maidenhead
# 902516  2021-12  -0.608141  51.483968  Windsor and Maidenhead
# 902517  2021-12  -0.580030  51.482030  Windsor and Maidenhead
# 902518  2021-12  -0.610450  51.480497  Windsor and Maidenhead
# 902519  2021-12  -2.135083  52.591503           Wolverhampton
#
# [902520 rows x 4 columns]

# %% [markdown]
# # Dropping the instances with null values

# %%
met_2021.isna().sum()
# Out:
# Month           0
# Longitude       0
# Latitude        0
# Borough      4556
# dtype: int64

# %%
met_2021.dropna(subset=['Borough'], inplace=True)

# %%
met_2021
# Out:
#           Month  Longitude   Latitude                 Borough
# 0       2021-01   0.880386  51.219190                 Ashford
# 1       2021-01   0.145888  51.593835    Barking and Dagenham
# 2       2021-01   0.134947  51.588063    Barking and Dagenham
# 3       2021-01   0.140192  51.582311    Barking and Dagenham
# 4       2021-01   0.141143  51.590873    Barking and Dagenham
# ...         ...        ...        ...                     ...
# 902515  2021-12  -0.606664  51.485155  Windsor and Maidenhead
# 902516  2021-12  -0.608141  51.483968  Windsor and Maidenhead
# 902517  2021-12  -0.580030  51.482030  Windsor and Maidenhead
# 902518  2021-12  -0.610450  51.480497  Windsor and Maidenhead
# 902519  2021-12  -2.135083  52.591503           Wolverhampton
#
# [897964 rows x 4 columns]

# %%
met_2021.isna().sum()
# Out:
# Month        0
# Longitude    0
# Latitude     0
# Borough      0
# dtype: int64

# %%
# drop long and lat columns
met_2021.drop(columns=['Longitude', 'Latitude'], inplace=True)
met_2021
# Out:
#           Month                 Borough
# 0       2021-01                 Ashford
# 1       2021-01    Barking and Dagenham
# 2       2021-01    Barking and Dagenham
# 3       2021-01    Barking and Dagenham
# 4       2021-01    Barking and Dagenham
# ...         ...                     ...
# 902515  2021-12  Windsor and Maidenhead
# 902516  2021-12  Windsor and Maidenhead
# 902517  2021-12  Windsor and Maidenhead
# 902518  2021-12  Windsor and Maidenhead
# 902519  2021-12           Wolverhampton
#
# [897964 rows x 2 columns]

# %% [markdown]
# # Checking what Locations have been identified by the location procassing

# %% [markdown]
# Apparently some locations identified by the script were not in London Boroughs. Therefore, only the London boroughs have to be retained.

# %%
boroughs = met_2021['Borough'].unique()
boroughs
# Out:
# array(['Ashford', 'Barking and Dagenham', 'Redbridge',
#        'No postal code found', 'Havering', 'Barnet', 'Enfield', 'Harrow',
#        'Haringey', 'Brent', 'Camden', 'Basildon', 'Bassetlaw', 'Bedford',
#        'Bexley', 'Greenwich', 'Bromley', 'Birmingham', 'Bolton',
#        'Bournemouth, Christchurch and Poole', 'Bracknell Forest',
#        'Ealing', 'Westminster', 'Hammersmith and Fulham', 'Brentwood',
#        'Bristol, City of', 'Lewisham', 'Southwark', 'Croydon',
#        'Broxbourne', 'Cambridge', 'Islington', 'City of London',
#        'Canterbury', 'Central Bedfordshire', 'Chelmsford', 'Cherwell',
#        'Cheshire West and Chester', 'Tower Hamlets', 'Colchester',
#        'Copeland', 'Coventry', 'Crawley', 'Sutton', 'Tandridge',
#        'Dacorum', 'Dartford', 'Dover', 'Hillingdon', 'Hounslow',
#        'East Cambridgeshire', 'East Hertfordshire', 'Elmbridge',
#        'Waltham Forest', 'Epping Forest', 'Epsom and Ewell', 'Fenland',
#        'Fylde', 'Gateshead', 'Gravesham', 'Guildford', 'Hackney',
#        'Kensington and Chelsea', 'Harlow', 'Hart', 'Hastings', 'Thurrock',
#        'Hertsmere', 'Spelthorne', 'Richmond upon Thames', 'Ipswich',
#        'North Northamptonshire', "King's Lynn and West Norfolk",
#        'Kingston upon Thames', 'Lambeth', 'Wandsworth', 'Merton', 'Leeds',
#        'Luton', 'Maidstone', 'Maldon', 'Medway', 'Melton',
#        'Milton Keynes', 'Mole Valley', 'Monmouthshire',
#        'Neath Port Talbot', 'New Forest', 'Newham', 'Newport',
#        'West Northamptonshire', 'North Norfolk', 'Norwich', 'Nottingham',
#        'Nuneaton and Bedworth', 'Peterborough', 'Preston', 'Reading',
#        'Redcar and Cleveland', 'Reigate and Banstead', 'Rochdale',
#        'Runnymede', 'Sefton', 'Sevenoaks', 'Sheffield', 'Slough',
#        'Southampton', 'Buckinghamshire', 'Southend-on-Sea', 'South Hams',
#        'Stevenage', 'Stoke-on-Trent', 'East Suffolk', 'Sunderland',
#        'Tameside', 'Tendring', 'Test Valley', 'Tonbridge and Malling',
#        'Uttlesford', 'Vale of White Horse', 'Walsall', 'Warwick',
#        'Watford', 'Waverley', 'Welwyn Hatfield', 'West Berkshire',
#        'Winchester', 'Wirral', 'Woking', 'Wolverhampton', 'Worcester',
#        'Wychavon', 'Arun', 'Bradford', 'Braintree', 'Breckland',
#        'Brighton and Hove', 'Broadland', 'Broxtowe', 'Bury',
#        'Castle Point', 'East Hampshire', 'Eastleigh',
#        'East Riding of Yorkshire', 'Exeter', 'High Peak', 'Horsham',
#        'Huntingdonshire', 'Kingston upon Hull, City of', 'Leicester',
#        'Liverpool', 'Malvern Hills', 'Middlesbrough', 'Mid Sussex',
#        'Newark and Sherwood', 'Northumberland', 'Oldham', 'Oxford',
#        'Portsmouth', 'Rochford', 'Rossendale', 'Rother', 'Rugby',
#        'Salford', 'Folkestone and Hythe', 'South Tyneside', 'St Albans',
#        'Stockton-on-Tees', 'Surrey Heath', 'Swale', 'Swindon',
#        'Somerset West and Taunton', 'Telford and Wrekin', 'Thanet',
#        'Three Rivers', 'Torbay', 'Trafford', 'Tunbridge Wells',
#        'Wakefield', 'Warrington', 'Wealden', 'Wigan', 'Ashfield', 'Wyre',
#        'Caerphilly', 'County Durham', 'Doncaster', 'Forest of Dean',
#        'Manchester', 'Newcastle upon Tyne', 'North Devon',
#        'North Somerset', 'Plymouth', 'Rotherham', 'Rushmoor',
#        'Shropshire', 'South Staffordshire', 'Stratford-on-Avon',
#        'Torfaen', 'Wiltshire', 'Windsor and Maidenhead', 'Worthing',
#        'Basingstoke and Deane', 'Bath and North East Somerset',
#        'Bromsgrove', 'Cardiff', 'Cornwall', 'Darlington', 'Derby',
#        'Dudley', 'Eastbourne', 'Herefordshire, County of',
#        'Hinckley and Bosworth', 'Kirklees', 'Mendip', 'Merthyr Tydfil',
#        'Mid Suffolk', 'North Hertfordshire', 'North Lincolnshire',
#        'North West Leicestershire', 'Pendle', 'Rushcliffe', 'Sandwell',
#        'South Holland', 'South Norfolk', 'South Oxfordshire',
#        'Staffordshire Moorlands', 'West Suffolk', 'Stockport', 'Swansea',
#        'Dorset', 'Barnsley', 'Blackpool', 'Boston', 'Cannock Chase',
#        'Cheltenham', 'Chesterfield', 'Chichester', 'Halton', 'Hambleton',
#        'Harrogate', 'Hartlepool', 'Lincoln', 'Mansfield',
#        'North Tyneside', 'Solihull', 'South Cambridgeshire',
#        'South Gloucestershire', 'Vale of Glamorgan', 'Torridge',
#        'Allerdale', 'Cheshire East', 'Lewes', 'Newcastle-under-Lyme',
#        'North East Lincolnshire', 'Rhondda Cynon Taf', 'Rutland',
#        'South Lakeland', 'South Somerset', 'Stroud', 'West Lancashire',
#        'Adur', 'Barrow-in-Furness', 'Blackburn with Darwen', 'Bolsover',
#        'Bridgend', 'Conwy', 'Denbighshire', 'Gosport', 'Havant',
#        'Lancaster', 'Mid Devon', 'Pembrokeshire', 'West Lindsey',
#        'Amber Valley', 'Babergh', 'Charnwood', 'Craven', 'Fareham',
#        'Gloucester', 'Great Yarmouth', 'Isle of Anglesey',
#        'Isle of Wight', 'Knowsley', 'North Kesteven', 'Richmondshire',
#        'Stafford', 'Tewkesbury', 'West Oxfordshire', 'Wokingham', 'York',
#        'Calderdale', 'Erewash', 'South Kesteven', 'Tamworth',
#        'Flintshire', 'Wrexham', 'Blaby', 'Burnley', 'Lichfield', 'Powys',
#        'Scarborough', 'South Derbyshire', 'South Ribble', 'West Devon',
#        'Carlisle', 'Carmarthenshire', 'East Lindsey',
#        'North Warwickshire', 'Teignbridge', 'Harborough', 'Sedgemoor'],
#       dtype=object)

# %%
boroughs.shape[0]
# Out:
# 312

# %%
met_2021[met_2021['Borough'] == 'Manchester']
# Out:
#           Month     Borough
# 181513  2021-03  Manchester
# 181514  2021-03  Manchester
# 254100  2021-04  Manchester
# 329995  2021-05  Manchester
# 329996  2021-05  Manchester
# 329997  2021-05  Manchester
# 329998  2021-05  Manchester
# 329999  2021-05  Manchester
# 488825  2021-07  Manchester
# 488826  2021-07  Manchester
# 488827  2021-07  Manchester
# 488828  2021-07  Manchester
# 566365  2021-08  Manchester
# 643420  2021-09  Manchester
# 643421  2021-09  Manchester
# 643422  2021-09  Manchester
# 643423  2021-09  Manchester
# 723306  2021-10  Manchester
# 723307  2021-10  Manchester
# 723308  2021-10  Manchester
# 803565  2021-11  Manchester
# 803566  2021-11  Manchester
# 803567  2021-11  Manchester
# 803568  2021-11  Manchester
# 803569  2021-11  Manchester
# 803570  2021-11  Manchester
# 878028  2021-12  Manchester
# 878029  2021-12  Manchester
# 878030  2021-12  Manchester

# %%
correct_boroughs = ['Kensington and Chelsea', 'Hounslow', 'Ealing', 'Westminster',
       'Southwark', 'Wandsworth', 'Hillingdon', 'Bexley',
       'Haringey', 'Tower Hamlets', 'Camden', 'Lambeth', 'Barnet',
       'Bromley', 'Sutton', 'Brent', 'Greenwich', 'Merton', 'Enfield',
       'Redbridge', 'Richmond upon Thames', 'Croydon', 'Waltham Forest',
       'Newham', 'Lewisham', 'Kingston upon Thames', 'Harrow',
       'Islington', 'Hackney', 'Havering', 'Hammersmith and Fulham',
       'Barking and Dagenham']

# %%
# met_sas_2021[met_sas_2021['Borough'] == 'Slough']
met_2021_correct = met_2021.loc[met_2021['Borough'].isin(correct_boroughs)]
met_2021_correct
# Out:
#           Month               Borough
# 1       2021-01  Barking and Dagenham
# 2       2021-01  Barking and Dagenham
# 3       2021-01  Barking and Dagenham
# 4       2021-01  Barking and Dagenham
# 5       2021-01  Barking and Dagenham
# ...         ...                   ...
# 902504  2021-12           Westminster
# 902505  2021-12           Westminster
# 902506  2021-12           Westminster
# 902507  2021-12           Westminster
# 902508  2021-12           Westminster
#
# [891395 rows x 2 columns]

# %%
correct_boroughs = met_2021_correct['Borough'].unique()
len(correct_boroughs)
# Out:
# 32

# %%
met_2021_correct.shape[0]
# Out:
# 891395

# %%
met_2021_correct
# Out:
#           Month               Borough
# 1       2021-01  Barking and Dagenham
# 2       2021-01  Barking and Dagenham
# 3       2021-01  Barking and Dagenham
# 4       2021-01  Barking and Dagenham
# 5       2021-01  Barking and Dagenham
# ...         ...                   ...
# 902504  2021-12           Westminster
# 902505  2021-12           Westminster
# 902506  2021-12           Westminster
# 902507  2021-12           Westminster
# 902508  2021-12           Westminster
#
# [891395 rows x 2 columns]

# %%
# group by borough and borough and count
met_2021_correct['Month'] = met_2021_correct['Month'].astype('datetime64[ns]')
met_2021_correct['Month'] = met_2021_correct['Month'].dt.strftime('%Y')
met_2021_correct
# Out:
# /var/folders/f7/5b6xj7tx2j980czxfkmrn8y00000gn/T/ipykernel_60543/3896584022.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   met_2021_correct['Month'] = met_2021_correct['Month'].astype('datetime64[ns]')
# /var/folders/f7/5b6xj7tx2j980czxfkmrn8y00000gn/T/ipykernel_60543/3896584022.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   met_2021_correct['Month'] = met_2021_correct['Month'].dt.strftime('%Y')
#        Month               Borough
# 1       2021  Barking and Dagenham
# 2       2021  Barking and Dagenham
# 3       2021  Barking and Dagenham
# 4       2021  Barking and Dagenham
# 5       2021  Barking and Dagenham
# ...      ...                   ...
# 902504  2021           Westminster
# 902505  2021           Westminster
# 902506  2021           Westminster
# 902507  2021           Westminster
# 902508  2021           Westminster
#
# [891395 rows x 2 columns]

# %%
# count the number of instances for each borough and month and add to a new column called 'Count' 
met_2021_correct['Count'] = met_2021_correct.groupby(['Borough', 'Month'])['Borough'].transform('count')
met_2021_correct
# Out:
# /var/folders/f7/5b6xj7tx2j980czxfkmrn8y00000gn/T/ipykernel_60543/122350700.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   met_2021_correct['Count'] = met_2021_correct.groupby(['Borough', 'Month'])['Borough'].transform('count')
#        Month               Borough  Count
# 1       2021  Barking and Dagenham  20964
# 2       2021  Barking and Dagenham  20964
# 3       2021  Barking and Dagenham  20964
# 4       2021  Barking and Dagenham  20964
# 5       2021  Barking and Dagenham  20964
# ...      ...                   ...    ...
# 902504  2021           Westminster  53164
# 902505  2021           Westminster  53164
# 902506  2021           Westminster  53164
# 902507  2021           Westminster  53164
# 902508  2021           Westminster  53164
#
# [891395 rows x 3 columns]

# %%
# drop duplicates
met_2021_correct.drop_duplicates(subset=['Borough', 'Month'], inplace=True)
met_2021_correct.reset_index(drop=True, inplace=True)
met_2021_correct
# Out:
# /var/folders/f7/5b6xj7tx2j980czxfkmrn8y00000gn/T/ipykernel_60543/1498699725.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   met_2021_correct.drop_duplicates(subset=['Borough', 'Month'], inplace=True)
#    Month                 Borough  Count
# 0   2021    Barking and Dagenham  20964
# 1   2021               Redbridge  27360
# 2   2021                Havering  19512
# 3   2021                  Barnet  31669
# 4   2021                 Enfield  33356
# 5   2021                  Harrow  17434
# 6   2021                Haringey  32366
# 7   2021                   Brent  31809
# 8   2021                  Camden  31562
# 9   2021                  Bexley  17729
# 10  2021               Greenwich  28642
# 11  2021                 Bromley  25679
# 12  2021                  Ealing  33427
# 13  2021             Westminster  53164
# 14  2021  Hammersmith and Fulham  22058
# 15  2021                Lewisham  30122
# 16  2021               Southwark  35801
# 17  2021                 Croydon  37104
# 18  2021               Islington  28321
# 19  2021           Tower Hamlets  38168
# 20  2021                  Sutton  15146
# 21  2021              Hillingdon  28916
# 22  2021                Hounslow  26746
# 23  2021          Waltham Forest  25912
# 24  2021                 Hackney  34046
# 25  2021  Kensington and Chelsea  20642
# 26  2021    Richmond upon Thames  13722
# 27  2021    Kingston upon Thames  12914
# 28  2021                 Lambeth  35614
# 29  2021              Wandsworth  28779
# 30  2021                  Merton  15547
# 31  2021                  Newham  37164

# %% [markdown]
# # Exporting the concatenated dataframes to a CSV

# %%
# export to csv
met_2021_correct.to_csv('../../Data/Police_Data/Crime_Data/crime_2021_wLocations/crime_cleaned.csv', index=False)
